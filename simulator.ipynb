# %%
#run the simulation of the diffusion planner on the minisplit 
# !python /home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_simulation.py \
  experiment_name=dp_mini_sanity_2 \
  scenario_builder=nuplan_mini \
  scenario_builder.data_root=/home/taimor/data1/nuplan-v1.1/splits/mini \
  +simulation=closed_loop_nonreactive_agents \
  planner=diffusion_planner \
  planner.diffusion_planner.config.args_file=/home/taimor/V0.1-diffusion-es/Diffusion-Planner/checkpoints/args.json \
  planner.diffusion_planner.ckpt_path=/home/taimor/V0.1-diffusion-es/Diffusion-Planner/checkpoints/model.pth \
  scenario_filter.shuffle=true scenario_filter.limit_total_scenarios=1 \
  worker=sequential verbose=true \
  'hydra.searchpath=[pkg://diffusion_planner.config.scenario_filter,pkg://diffusion_planner.config,pkg://nuplan.planning.script.config.common,pkg://nuplan.planning.script.experiments]'

# %%
import sys
import os

# --- 0. Patch asyncio for Jupyter ---
# This is required to fix "RuntimeError: asyncio.run() cannot be called from a running event loop"
# because Jupyter/IPython already runs its own event loop.
import nest_asyncio
nest_asyncio.apply()
# ------------------------------------

# --- 1. Set up Python paths ---
# Add the project subdirectories to the Python path.
# Assumes you are running this notebook from '/home/taimor/V0.1-diffusion-es/'
devkit_path = 'nuplan-devkit'
if devkit_path not in sys.path:
    sys.path.insert(0, devkit_path)

# Add the Diffusion-Planner project root to the Python path
# so that hydra's `pkg://diffusion_planner` resolver can find it.
planner_path = 'Diffusion-Planner'
if planner_path not in sys.path:
    sys.path.insert(0, planner_path)

print(f"Updated sys.path:\n{sys.path}\n")

try:
    # --- 2. Import the main function ---
    # Now that the path is set, we can import the main function from the script.
    # The `@hydra.main` decorator is already applied.
    from nuplan.planning.script.run_simulation import main as run_simulation_main

    # --- 3. Define the arguments ---
    # This list mimics your shell command.
    # The first item is the script name, which hydra expects.
    script_path = 'nuplan-devkit/nuplan/planning/script/run_simulation.py'
    
    args = [
        script_path,  # sys.argv[0]
        "experiment_name=dp_mini_sanity_3",
        "scenario_builder=nuplan_mini",
        "scenario_builder.data_root=/home/taimor/data1/nuplan-v1.1/splits/mini", # Kept as absolute path
        "+simulation=closed_loop_nonreactive_agents",
        "planner=diffusion_planner",
        "planner.diffusion_planner.config.args_file=/home/taimor/projecta/Project-diffusion/Diffusion-Planner/checkpoints/args.json",
        "planner.diffusion_planner.ckpt_path=/home/taimor/projecta/Project-diffusion/Diffusion-Planner/checkpoints/model.pth",
        "scenario_filter.shuffle=true",
        "scenario_filter.limit_total_scenarios=1",
        "worker=sequential",
        "verbose=true",
        "hydra.searchpath=[pkg://diffusion_planner.config.scenario_filter,pkg://diffusion_planner.config,pkg://nuplan.planning.script.config.common,pkg://nuplan.planning.script.experiments]"
    ]

    # --- 4. Run the simulation ---
    print("Backing up original sys.argv...")
    original_argv = list(sys.argv)  # Make a copy
    
    try:
        print("Setting new sys.argv for hydra...")
        sys.argv = args
        print(f"Running simulation with args: {sys.argv}")
        
        # Call the hydra-decorated main function
        run_simulation_main()
        
        print("\nSimulation finished.")
        
    except Exception as e:
        print(f"\nAn error occurred during simulation: {e}")
        import traceback
        traceback.print_exc()
        
    finally:
        # Restore the original sys.argv so it doesn't affect other notebook cells
        print("Restoring original sys.argv...")
        sys.argv = original_argv

except ImportError as e:
    print(f"Error: Failed to import modules: {e}")
    print("Please double-check the paths set in this cell:")
    print(f"Devkit path: {devkit_path}")
    print(f"Planner path: {planner_path}")
    print("Ensure these directories exist and contain the correct packages.")
# Out:
# Updated sys.path:
# ['Diffusion-Planner', 'nuplan-devkit', '/home/taimor/miniconda/envs/nuplan/lib/python39.zip', '/home/taimor/miniconda/envs/nuplan/lib/python3.9', '/home/taimor/miniconda/envs/nuplan/lib/python3.9/lib-dynload', '', '/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages', '/home/taimor/V0.1-diffusion-es/nuplan-devkit', '/home/taimor/V0.1-diffusion-es/Diffusion-Planner']
# INFO:nuplan.planning.script.utils:Setting default NUPLAN_EXP_ROOT: /home/taimor/nuplan/exp
# /home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/run_simulation.py:100: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path=CONFIG_PATH, config_name=CONFIG_NAME)
# /home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'default_simulation': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# Backing up original sys.argv...
# Setting new sys.argv for hydra...
# Running simulation with args: ['nuplan-devkit/nuplan/planning/script/run_simulation.py', 'experiment_name=dp_mini_sanity_3', 'scenario_builder=nuplan_mini', 'scenario_builder.data_root=/home/taimor/data1/nuplan-v1.1/splits/mini', '+simulation=closed_loop_nonreactive_agents', 'planner=diffusion_planner', 'planner.diffusion_planner.config.args_file=/home/taimor/projecta/Project-diffusion/Diffusion-Planner/checkpoints/args.json', 'planner.diffusion_planner.ckpt_path=/home/taimor/projecta/Project-diffusion/Diffusion-Planner/checkpoints/model.pth', 'scenario_filter.shuffle=true', 'scenario_filter.limit_total_scenarios=1', 'worker=sequential', 'verbose=true', 'hydra.searchpath=[pkg://diffusion_planner.config.scenario_filter,pkg://diffusion_planner.config,pkg://nuplan.planning.script.config.common,pkg://nuplan.planning.script.experiments]']
# /home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# Global seed set to 0
# INFO:nuplan.planning.script.builders.main_callback_builder:Building MultiMainCallback...
# INFO:nuplan.planning.script.builders.main_callback_builder:Building MultiMainCallback: 4...DONE!
# 2025-11-17 19:53:36,483 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2025-11-17 19:53:36,486 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: Sequential
# 2025-11-17 19:53:36,487 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 1
# Number of GPUs per node: 0
# Number of threads across all nodes: 1
# 2025-11-17 19:53:36,487 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2025-11-17 19:53:36,488 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2025-11-17 19:53:36,488 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /home/taimor/nuplan/exp/exp/dp_mini_sanity_3/closed_loop_nonreactive_agents/2025.11.17.19.53.31
#
# 2025-11-17 19:53:36,497 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2025-11-17 19:53:36,499 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2025-11-17 19:53:36,500 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2025-11-17 19:53:36,500 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2025-11-17 19:53:36,500 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2025-11-17 19:53:36,501 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2025-11-17 19:53:36,501 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2025-11-17 19:53:36,543 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2025-11-17 19:53:36,544 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2025-11-17 19:53:36,548 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2025-11-17 19:53:36,654 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2025-11-17 19:53:37,240 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2025-11-17 19:53:37,241 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 1 scenarios...
# 2025-11-17 19:53:39,207 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2025-11-17 19:53:39,208 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2025-11-17 19:53:39,208 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2025-11-17 19:53:39,208 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 1 simulations using Sequential!
# 2025-11-17 19:53:39,209 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:116}  Submitting 1 tasks!
# 2025-11-17 19:55:37,654 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 1
# 2025-11-17 19:55:37,655 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2025-11-17 19:55:37,655 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2025-11-17 19:55:37,682 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /home/taimor/nuplan/exp/exp/dp_mini_sanity_3/closed_loop_nonreactive_agents/2025.11.17.19.53.31/runner_report.parquet
# 2025-11-17 19:55:37,682 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:02:11 [HH:MM:SS]
# 2025-11-17 19:55:37,798 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2025-11-17 19:55:37,956 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: closed_loop_nonreactive_agents_weighted_average
# 2025-11-17 19:55:37,988 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms:  12%|█▏        | 2/17 [00:01<00:08,  1.80it/s]
# 2025-11-17 19:55:39,422 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-17 19:55:39,429 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-17 19:55:39,443 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-17 19:55:39,449 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-17 19:55:39,464 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-17 19:55:39,470 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-17 19:55:39,481 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-17 19:55:39,488 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Rendering histograms:  35%|███▌      | 6/17 [00:02<00:03,  3.05it/s]
# 2025-11-17 19:55:40,436 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-11-17 19:55:40,442 INFO {/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/matplotlib/category.py:223}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Rendering histograms: 100%|██████████| 17/17 [00:05<00:00,  3.10it/s]
# 2025-11-17 19:55:49,333 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:11 [HH:MM:SS]
# 2025-11-17 19:55:49,334 INFO {/home/taimor/projecta/Project-diffusion/nuplan-devkit/nuplan/planning/script/run_simulation.py:81}  Finished running simulation!
#
# Simulation finished.
# Restoring original sys.argv...

# %%
#  visualize in nuboard
# !python /home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_nuboard.py \
  port_number=7007 \
  worker=sequential \
  simulation_path='["/home/taimor/nuplan/exp/exp/dp_mini_sanity/closed_loop_nonreactive_agents/"]' \
  scenario_builder.data_root=/home/taimor/data1/nuplan-v1.1/splits/mini \
  scenario_builder.map_root=/home/taimor/data1/maps \
# Out:
# 209.94s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# /home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_nuboard.py:67: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path=CONFIG_PATH, config_name=CONFIG_NAME)
# /home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'default_nuboard': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# /home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# INFO:nuplan.planning.script.builders.scenario_building_builder:Building AbstractScenarioBuilder...
# INFO:nuplan.planning.script.builders.scenario_building_builder:Building AbstractScenarioBuilder...DONE!
# INFO:nuplan.planning.nuboard.utils.utils:No available nuBoard files are found.
# INFO:nuplan.planning.nuboard.nuboard:Opening Bokeh application on http://localhost:7007/
# INFO:nuplan.planning.nuboard.nuboard:Async rendering is set to: True
# INFO:bokeh.server.server:Starting Bokeh server version 2.4.3 (running on Tornado 6.5.2)
# WARNING:bokeh.server.util:Host wildcard '*' will allow connections originating from multiple (or possibly all) hostnames or IPs. Use non-wildcard values to restrict access explicitly
# INFO:bokeh.server.tornado:User authentication hooks NOT provided (default user enabled)
# INFO:nuplan.planning.nuboard.base.simulation_tile:Minimum frame time=0.017 s
# INFO:tornado.access:200 GET / (::1) 577.29ms
# INFO:tornado.access:200 GET /resource/spectre.min.css (::1) 4.72ms
# INFO:tornado.access:200 GET /resource/css/scenario.css (::1) 1.92ms
# INFO:tornado.access:200 GET /resource/spectre-exp.min.css (::1) 2.31ms
# INFO:tornado.access:200 GET /resource/spectre-icons.min.css (::1) 3.21ms
# INFO:tornado.access:200 GET /resource/style.css (::1) 3.96ms
# INFO:tornado.access:200 GET /resource/css/overview.css (::1) 4.73ms
# INFO:tornado.access:200 GET /resource/css/histogram.css (::1) 1.54ms
# INFO:tornado.access:200 GET /resource/css/cloud.css (::1) 3.55ms
# INFO:tornado.access:200 GET /static/js/bokeh.min.js?v=3c61e952b808bb7e346ce828a565a5f23aaf7708d034fa9d0906403813355d45bb4e8d8b0b23a93f032c76831d4f0221846f28699c7f5147caa62e0d31668314 (::1) 3.40ms
# INFO:tornado.access:200 GET /static/js/bokeh-gl.min.js?v=e5df31fd9010eacff0aa72d315264604b5e34972ba445acea6fce98080eecf33acf2d2986126360faaa5852813cffa16f6f6f4889923318300f062497c02da4e (::1) 3.70ms
# INFO:tornado.access:200 GET /static/js/bokeh-widgets.min.js?v=8a1ff6f5aa0d967f4998d275803bbb111d928fd9f605ef9e1f30cfd021df0e77224ee3d13f83edb3a942f6e4ccc569ee5dd8951a8aa6cb600602463b90c65a87 (::1) 4.04ms
# INFO:tornado.access:200 GET /static/js/bokeh-tables.min.js?v=ae2903e57cf57f52819fdf4d938c648982b51c34f73b6e653a0f3bb3c8ab44f338505931ace43eafc1636e215492e2314acf54c54baffb47813b86b4923a7fe0 (::1) 1.55ms
# INFO:tornado.access:200 GET /static/js/bokeh-mathjax.min.js?v=176c36fdbcd8fc1019fc828101a2804081a35baf4018d7f2633cd263156b593aa73112f400112b662daa0590138b74851bc91f1f2a5fbf5416ee8c876c3e0d0c (::1) 3.79ms
# INFO:tornado.access:200 GET /resource/scripts/utils.js (::1) 4.52ms
# INFO:tornado.access:200 GET /resource/motional_logo.png (::1) 2.34ms
# INFO:tornado.access:101 GET /ws (::1) 1.26ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:bokeh.server.views.ws:ServerConnection created
# WARNING:tornado.access:404 GET /favicon.ico (::1) 0.53ms
# INFO:nuplan.planning.nuboard.base.simulation_tile:Minimum frame time=0.017 s
# INFO:tornado.access:200 GET / (::1) 143.93ms
# INFO:tornado.access:101 GET /ws (::1) 1.71ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:bokeh.server.views.ws:ServerConnection created
# INFO:bokeh.server.views.ws:WebSocket connection closed: code=1001, reason=None
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0205 seconds.
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0160 seconds.
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0159 seconds.
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0147 seconds.
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0197 seconds.
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0147 seconds.
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0159 seconds.
# INFO:nuplan.planning.nuboard.tabs.scenario_tab:Rending scenario plot takes 0.0187 seconds.
# INFO:bokeh.server.views.ws:WebSocket connection closed: code=1001, reason=None
# Traceback (most recent call last):
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_nuboard.py", line 78, in <module>
#     main()
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/main.py", line 94, in decorated_main
#     _run_hydra(
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/utils.py", line 394, in _run_hydra
#     _run_app(
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/utils.py", line 457, in _run_app
#     run_and_report(
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/utils.py", line 220, in run_and_report
#     return func()
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/utils.py", line 458, in <lambda>
#     lambda: hydra.run(
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/_internal/hydra.py", line 119, in run
#     ret = run_job(
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/hydra/core/utils.py", line 186, in run_job
#     ret.return_value = task_function(task_cfg)
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_nuboard.py", line 74, in main
#     nuboard.run()
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/nuboard/nuboard.py", line 112, in run
#     io_loop.start()
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/nest_asyncio.py", line 81, in run_forever
#     self._run_once()
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/nest_asyncio.py", line 115, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
# ^C
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/ray/_private/worker.py", line 1096, in wrapper
#     return func(*args, **kwargs)
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/ray/_private/worker.py", line 2014, in shutdown
#     from ray.dag.compiled_dag_node import _shutdown_all_compiled_dags
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/ray/dag/__init__.py", line 1, in <module>
#     from ray.dag.dag_node import DAGNode
#   File "/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/ray/dag/dag_node.py", line 2, in <module>
#     from ray.experimental.channel.auto_transport_type import AutoTransportType
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 986, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 680, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 941, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1040, in get_data
# KeyboardInterrupt
