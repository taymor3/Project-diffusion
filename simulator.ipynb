# %%
#run the simulation of the diffusion planner on the minisplit 
# !python /home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_simulation.py \
  experiment_name=dp_mini_sanity_2 \
  scenario_builder=nuplan_mini \
  scenario_builder.data_root=/home/taimor/data1/nuplan-v1.1/splits/mini \
  +simulation=closed_loop_nonreactive_agents \
  planner=diffusion_planner \
  planner.diffusion_planner.config.args_file=/home/taimor/V0.1-diffusion-es/Diffusion-Planner/checkpoints/args.json \
  planner.diffusion_planner.ckpt_path=/home/taimor/V0.1-diffusion-es/Diffusion-Planner/checkpoints/model.pth \
  scenario_filter.shuffle=true scenario_filter.limit_total_scenarios=1 \
  worker=sequential verbose=true \
  'hydra.searchpath=[pkg://diffusion_planner.config.scenario_filter,pkg://diffusion_planner.config,pkg://nuplan.planning.script.config.common,pkg://nuplan.planning.script.experiments]'

# %%
import sys
import os

# --- 0. Patch asyncio for Jupyter ---
# This is required to fix "RuntimeError: asyncio.run() cannot be called from a running event loop"
# because Jupyter/IPython already runs its own event loop.
import nest_asyncio
nest_asyncio.apply()
# ------------------------------------

# --- 1. Set up Python paths ---
# Add the project subdirectories to the Python path.
# Assumes you are running this notebook from '/home/taimor/V0.1-diffusion-es/'
devkit_path = 'nuplan-devkit'
if devkit_path not in sys.path:
    sys.path.insert(0, devkit_path)

# Add the Diffusion-Planner project root to the Python path
# so that hydra's `pkg://diffusion_planner` resolver can find it.
planner_path = 'Diffusion-Planner'
if planner_path not in sys.path:
    sys.path.insert(0, planner_path)

print(f"Updated sys.path:\n{sys.path}\n")

try:
    # --- 2. Import the main function ---
    # Now that the path is set, we can import the main function from the script.
    # The `@hydra.main` decorator is already applied.
    from nuplan.planning.script.run_simulation import main as run_simulation_main

    # --- 3. Define the arguments ---
    # This list mimics your shell command.
    # The first item is the script name, which hydra expects.
    script_path = 'nuplan-devkit/nuplan/planning/script/run_simulation.py'
    
    args = [
        script_path,  # sys.argv[0]
        "experiment_name=dp_mini_sanity_3",
        "scenario_builder=nuplan_mini",
        "scenario_builder.data_root=/home/taimor/data1/nuplan-v1.1/splits/mini", # Kept as absolute path
        "+simulation=closed_loop_nonreactive_agents",
        "planner=diffusion_planner",
        "planner.diffusion_planner.config.args_file=/home/taimor/V0.1-diffusion-es/Diffusion-Planner/checkpoints/args.json",
        "planner.diffusion_planner.ckpt_path=/home/taimor/V0.1-diffusion-es/Diffusion-Planner/checkpoints/model.pth",
        "scenario_filter.shuffle=true",
        "scenario_filter.limit_total_scenarios=1",
        "worker=sequential",
        "verbose=true",
        "hydra.searchpath=[pkg://diffusion_planner.config.scenario_filter,pkg://diffusion_planner.config,pkg://nuplan.planning.script.config.common,pkg://nuplan.planning.script.experiments]"
    ]

    # --- 4. Run the simulation ---
    print("Backing up original sys.argv...")
    original_argv = list(sys.argv)  # Make a copy
    
    try:
        print("Setting new sys.argv for hydra...")
        sys.argv = args
        print(f"Running simulation with args: {sys.argv}")
        
        # Call the hydra-decorated main function
        run_simulation_main()
        
        print("\nSimulation finished.")
        
    except Exception as e:
        print(f"\nAn error occurred during simulation: {e}")
        import traceback
        traceback.print_exc()
        
    finally:
        # Restore the original sys.argv so it doesn't affect other notebook cells
        print("Restoring original sys.argv...")
        sys.argv = original_argv

except ImportError as e:
    print(f"Error: Failed to import modules: {e}")
    print("Please double-check the paths set in this cell:")
    print(f"Devkit path: {devkit_path}")
    print(f"Planner path: {planner_path}")
    print("Ensure these directories exist and contain the correct packages.")
# Out:
# Updated sys.path:
# ['/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages/ray/thirdparty_files', 'Diffusion-Planner', 'nuplan-devkit', '/home/taimor/miniconda/envs/nuplan/lib/python39.zip', '/home/taimor/miniconda/envs/nuplan/lib/python3.9', '/home/taimor/miniconda/envs/nuplan/lib/python3.9/lib-dynload', '', '/home/taimor/miniconda/envs/nuplan/lib/python3.9/site-packages', '/home/taimor/V0.1-diffusion-es/nuplan-devkit', '/home/taimor/V0.1-diffusion-es/Diffusion-Planner']
#
# Backing up original sys.argv...
# Setting new sys.argv for hydra...
# Running simulation with args: ['nuplan-devkit/nuplan/planning/script/run_simulation.py', 'experiment_name=dp_mini_sanity_3', 'scenario_builder=nuplan_mini', 'scenario_builder.data_root=/home/taimor/data1/nuplan-v1.1/splits/mini', '+simulation=closed_loop_nonreactive_agents', 'planner=diffusion_planner', 'planner.diffusion_planner.config.args_file=/home/taimor/V0.1-diffusion-es/Diffusion-Planner/checkpoints/args.json', 'planner.diffusion_planner.ckpt_path=/home/taimor/V0.1-diffusion-es/Diffusion-Planner/checkpoints/model.pth', 'scenario_filter.shuffle=true', 'scenario_filter.limit_total_scenarios=1', 'worker=sequential', 'verbose=true', 'hydra.searchpath=[pkg://diffusion_planner.config.scenario_filter,pkg://diffusion_planner.config,pkg://nuplan.planning.script.config.common,pkg://nuplan.planning.script.experiments]']
# Global seed set to 0
# 2025-11-02 15:36:08,350 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2025-11-02 15:36:08,443 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2025-11-02 15:36:08,894 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2025-11-02 15:36:08,894 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2025-11-02 15:36:08,898 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: Sequential
# 2025-11-02 15:36:08,898 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: Sequential
# 2025-11-02 15:36:08,898 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 1
# Number of GPUs per node: 0
# Number of threads across all nodes: 1
# 2025-11-02 15:36:08,898 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 1
# Number of GPUs per node: 0
# Number of threads across all nodes: 1
# 2025-11-02 15:36:08,899 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2025-11-02 15:36:08,899 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2025-11-02 15:36:08,899 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2025-11-02 15:36:08,899 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2025-11-02 15:36:08,899 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /home/taimor/nuplan/exp/exp/dp_mini_sanity_3/closed_loop_nonreactive_agents/2025.11.02.15.36.03
#
# 2025-11-02 15:36:08,899 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /home/taimor/nuplan/exp/exp/dp_mini_sanity_3/closed_loop_nonreactive_agents/2025.11.02.15.36.03
#
# 2025-11-02 15:36:08,911 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2025-11-02 15:36:08,911 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2025-11-02 15:36:08,912 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2025-11-02 15:36:08,912 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2025-11-02 15:36:08,913 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2025-11-02 15:36:08,913 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2025-11-02 15:36:08,913 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2025-11-02 15:36:08,913 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2025-11-02 15:36:08,913 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2025-11-02 15:36:08,913 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2025-11-02 15:36:08,914 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2025-11-02 15:36:08,914 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2025-11-02 15:36:08,914 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2025-11-02 15:36:08,914 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2025-11-02 15:36:08,968 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2025-11-02 15:36:08,968 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2025-11-02 15:36:08,968 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2025-11-02 15:36:08,968 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2025-11-02 15:36:08,972 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2025-11-02 15:36:08,972 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2025-11-02 15:36:09,286 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2025-11-02 15:36:09,286 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2025-11-02 15:36:09,355 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2025-11-02 15:36:09,355 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2025-11-02 15:36:09,355 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 1 scenarios...
# 2025-11-02 15:36:09,355 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 1 scenarios...
# 2025-11-02 15:36:09,582 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2025-11-02 15:36:09,582 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2025-11-02 15:36:09,584 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2025-11-02 15:36:09,584 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2025-11-02 15:36:09,584 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2025-11-02 15:36:09,584 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2025-11-02 15:36:09,585 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 1 simulations using Sequential!
# 2025-11-02 15:36:09,585 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 1 simulations using Sequential!
# 2025-11-02 15:36:09,585 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:116}  Submitting 1 tasks!
# 2025-11-02 15:36:09,585 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:116}  Submitting 1 tasks!
# Sequential:   0%|          | 0/1 [00:00<?, ?it/s]
# parent step: 0
# Sequential:   0%|          | 0/1 [00:01<?, ?it/s]Traceback (most recent call last):
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
#     return sim_runner.run()
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 113, in run
#     trajectory = self.planner.compute_trajectory(planner_input)
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 108, in compute_trajectory
#     raise e
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 105, in compute_trajectory
#     trajectory = self.compute_planner_trajectory(current_input)
#   File "/home/taimor/V0.1-diffusion-es/Diffusion-Planner/diffusion_planner/planner/planner.py", line 186, in compute_planner_trajectory
#     # (You can set m>1, but keep it small to avoid ego-frame drift.)
#   File "/home/taimor/V0.1-diffusion-es/Diffusion-Planner/diffusion_planner/planner/planner.py", line 149, in imaginary_input_history_consistent
# NameError: name 'new_inputs' is not defined
# 2025-11-02 15:36:11,351 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:32}  ----------- Simulation failed: with the following trace:
# 2025-11-02 15:36:11,351 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:32}  ----------- Simulation failed: with the following trace:
# 2025-11-02 15:36:11,362 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:34}  Simulation failed with error:
#  name 'new_inputs' is not defined
# 2025-11-02 15:36:11,362 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:34}  Simulation failed with error:
#  name 'new_inputs' is not defined
# 2025-11-02 15:36:11,380 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:38}
# Failed simulation [log,token]:
#  [2021.07.16.20.45.29_veh-35_01095_01486, 720a87b482495a98]
#
# 2025-11-02 15:36:11,380 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:38}
# Failed simulation [log,token]:
#  [2021.07.16.20.45.29_veh-35_01095_01486, 720a87b482495a98]
#
# 2025-11-02 15:36:11,390 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:40}  ----------- Simulation failed!
# 2025-11-02 15:36:11,390 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:40}  ----------- Simulation failed!
# 2025-11-02 15:36:11,411 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:123}  Failed Simulation.
#  'Traceback (most recent call last):
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
#     return sim_runner.run()
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 113, in run
#     trajectory = self.planner.compute_trajectory(planner_input)
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 108, in compute_trajectory
#     raise e
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 105, in compute_trajectory
#     trajectory = self.compute_planner_trajectory(current_input)
#   File "/home/taimor/V0.1-diffusion-es/Diffusion-Planner/diffusion_planner/planner/planner.py", line 186, in compute_planner_trajectory
#     # (You can set m>1, but keep it small to avoid ego-frame drift.)
#   File "/home/taimor/V0.1-diffusion-es/Diffusion-Planner/diffusion_planner/planner/planner.py", line 149, in imaginary_input_history_consistent
# NameError: name 'new_inputs' is not defined
# '
# 2025-11-02 15:36:11,411 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:123}  Failed Simulation.
#  'Traceback (most recent call last):
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py", line 27, in run_simulation
#     return sim_runner.run()
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/simulations_runner.py", line 113, in run
#     trajectory = self.planner.compute_trajectory(planner_input)
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 108, in compute_trajectory
#     raise e
#   File "/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/planner/abstract_planner.py", line 105, in compute_trajectory
#     trajectory = self.compute_planner_trajectory(current_input)
#   File "/home/taimor/V0.1-diffusion-es/Diffusion-Planner/diffusion_planner/planner/planner.py", line 186, in compute_planner_trajectory
#     # (You can set m>1, but keep it small to avoid ego-frame drift.)
#   File "/home/taimor/V0.1-diffusion-es/Diffusion-Planner/diffusion_planner/planner/planner.py", line 149, in imaginary_input_history_consistent
# NameError: name 'new_inputs' is not defined
# '
# 2025-11-02 15:36:11,411 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 0
# 2025-11-02 15:36:11,411 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 0
# 2025-11-02 15:36:11,412 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 1
# 2025-11-02 15:36:11,412 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 1
# 2025-11-02 15:36:11,412 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:132}  Failed simulations [log, token]:
# [2021.07.16.20.45.29_veh-35_01095_01486, 720a87b482495a98]
#
# 2025-11-02 15:36:11,412 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:132}  Failed simulations [log, token]:
# [2021.07.16.20.45.29_veh-35_01095_01486, 720a87b482495a98]
#
# 2025-11-02 15:36:11,412 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2025-11-02 15:36:11,412 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2025-11-02 15:36:11,473 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /home/taimor/nuplan/exp/exp/dp_mini_sanity_3/closed_loop_nonreactive_agents/2025.11.02.15.36.03/runner_report.parquet
# 2025-11-02 15:36:11,473 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /home/taimor/nuplan/exp/exp/dp_mini_sanity_3/closed_loop_nonreactive_agents/2025.11.02.15.36.03/runner_report.parquet
# 2025-11-02 15:36:11,475 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:00:03 [HH:MM:SS]
# 2025-11-02 15:36:11,475 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:00:03 [HH:MM:SS]
# 2025-11-02 15:36:11,477 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2025-11-02 15:36:11,477 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2025-11-02 15:36:11,479 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:61}  closed_loop_nonreactive_agents_weighted_average: No metric files found for aggregation!
# 2025-11-02 15:36:11,479 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:61}  closed_loop_nonreactive_agents_weighted_average: No metric files found for aggregation!
# 2025-11-02 15:36:11,479 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:62}  If you didn't expect this, ensure that the challenge name is part of your submitted job name.
# 2025-11-02 15:36:11,479 WARNING {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:62}  If you didn't expect this, ensure that the challenge name is part of your submitted job name.
# 2025-11-02 15:36:11,479 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# 2025-11-02 15:36:11,479 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 0it [00:00, ?it/s]
# 2025-11-02 15:36:11,488 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:00 [HH:MM:SS]
# 2025-11-02 15:36:11,488 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:00 [HH:MM:SS]
# 2025-11-02 15:36:11,490 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_simulation.py:81}  Finished running simulation!
# 2025-11-02 15:36:11,490 INFO {/home/taimor/V0.1-diffusion-es/nuplan-devkit/nuplan/planning/script/run_simulation.py:81}  Finished running simulation!
#
# Simulation finished.
# Restoring original sys.argv...
